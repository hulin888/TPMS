# %%
# !ffmpeg -i '/home/sanjay/Desktop/TNMS_VM/data/videos/afe05837-4924-467e-bc90-7cc542b0fa12/87_2021-08-25_155408-converted.mp4' -ss 00:00:03 -t 00:00:08 -async 1 cut.mp4
# Out:
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-liblensfun --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55ae0c7b7700] st: 0 edit list: 1 Missing key frame while searching for timestamp: 0
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55ae0c7b7700] st: 0 edit list 1 Cannot find an index entry before timestamp: 0.
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/sanjay/Desktop/TNMS_VM/data/videos/afe05837-4924-467e-bc90-7cc542b0fa12/87_2021-08-25_155408-converted.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: mp41avc1
#     creation_time   : 2021-08-26T15:19:56.000000Z
#     encoder         : vlc 3.0.16 stream output
#     encoder-eng     : vlc 3.0.16 stream output
#   Duration: 00:02:44.12, start: 0.000000, bitrate: 4364 kb/s
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 4361 kb/s, 24.97 fps, 25 tbr, 1000k tbn, 49.93 tbc (default)
#     Metadata:
#       creation_time   : 2021-08-26T15:19:56.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ae0c7bd680] using SAR=1/1
# [libx264 @ 0x55ae0c7bd680] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ae0c7bd680] profile High, level 3.1
# [libx264 @ 0x55ae0c7bd680] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'cut.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: mp41avc1
#     encoder         : Lavf58.29.100
#     Stream #0:0(eng): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       creation_time   : 2021-08-26T15:19:56.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  200 fps= 50 q=-1.0 Lsize=    3666kB time=00:00:07.88 bitrate=3811.2kbits/s speed=1.98x
# video:3663kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.087475%
# [libx264 @ 0x55ae0c7bd680] frame I:1     Avg QP:22.58  size:137240
# [libx264 @ 0x55ae0c7bd680] frame P:50    Avg QP:23.61  size: 47756
# [libx264 @ 0x55ae0c7bd680] frame B:149   Avg QP:30.05  size:  8222
# [libx264 @ 0x55ae0c7bd680] consecutive B-frames:  0.5%  0.0%  1.5% 98.0%
# [libx264 @ 0x55ae0c7bd680] mb I  I16..4:  2.5% 56.3% 41.2%
# [libx264 @ 0x55ae0c7bd680] mb P  I16..4:  0.7%  1.5%  1.8%  P16..4: 45.0% 25.4% 15.4%  0.0%  0.0%    skip:10.4%
# [libx264 @ 0x55ae0c7bd680] mb B  I16..4:  0.1%  0.0%  0.2%  B16..8: 61.8%  5.5%  1.2%  direct: 1.4%  skip:29.8%  L0:56.1% L1:34.3% BI: 9.6%
# [libx264 @ 0x55ae0c7bd680] 8x8 transform intra:39.3% inter:34.9%
# [libx264 @ 0x55ae0c7bd680] coded y,uvDC,uvAC intra: 76.0% 35.3% 10.6% inter: 19.4% 5.5% 0.1%
# [libx264 @ 0x55ae0c7bd680] i16 v,h,dc,p: 25% 29% 25% 21%
# [libx264 @ 0x55ae0c7bd680] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20% 21% 27%  4%  5%  4%  8%  5%  7%
# [libx264 @ 0x55ae0c7bd680] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 27% 15%  6%  5%  4%  7%  6%  5%
# [libx264 @ 0x55ae0c7bd680] i8c dc,h,v,p: 58% 22% 16%  4%
# [libx264 @ 0x55ae0c7bd680] Weighted P-Frames: Y:8.0% UV:0.0%
# [libx264 @ 0x55ae0c7bd680] ref P L0: 68.1%  8.7% 17.8%  4.6%  0.8%
# [libx264 @ 0x55ae0c7bd680] ref B L0: 90.9%  7.7%  1.4%
# [libx264 @ 0x55ae0c7bd680] ref B L1: 97.4%  2.6%
# [libx264 @ 0x55ae0c7bd680] kb/s:3750.09

# %%
import os, shutil
from datetime import timedelta

vidpath = '/home/sanjay/Desktop/TNMS_VM/data/videos/afe05837-4924-467e-bc90-7cc542b0fa12/87_2021-08-25_155408-converted.mp4'
imagename = 'image-0037.jpg'
videoclip_dir = '/home/sanjay/Desktop/TNMS_VM/data/videoclips'
job_id = 'xyz'
img_time = os.path.splitext(imagename)[0]
img_time = int(img_time.split('-')[-1]) -1
img_timefrom = timedelta(seconds=img_time-5)
img_timeto = timedelta(seconds=img_time+5)
savclippath = os.path.join(videoclip_dir, job_id, str(img_time))
if os.path.isdir(savclippath):
    shutil.rmtree(savclippath)
os.makedirs(savclippath)

# ffmpeg -i movie.mp4 -ss 00:00:03 -t 00:00:08 -async 1 cut.mp4

command = 'ffmpeg  -i '+vidpath+' -ss '+str(img_timefrom)+' -t '+'00:00:10'+ ' -async 1 '+savclippath+'/clip.mp4'
os.system(command)
# Out:
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-liblensfun --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55d54aa8c700] st: 0 edit list: 1 Missing key frame while searching for timestamp: 0
# [mov,mp4,m4a,3gp,3g2,mj2 @ 0x55d54aa8c700] st: 0 edit list 1 Cannot find an index entry before timestamp: 0.
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/home/sanjay/Desktop/TNMS_VM/data/videos/afe05837-4924-467e-bc90-7cc542b0fa12/87_2021-08-25_155408-converted.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: mp41avc1
#     creation_time   : 2021-08-26T15:19:56.000000Z
#     encoder         : vlc 3.0.16 stream output
#     encoder-eng     : vlc 3.0.16 stream output
#   Duration: 00:02:44.12, start: 0.000000, bitrate: 4364 kb/s
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 4361 kb/s, 24.97 fps, 25 tbr, 1000k tbn, 49.93 tbc (default)
#     Metadata:
#       creation_time   : 2021-08-26T15:19:56.000000Z
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d54aa92680] using SAR=1/1
# [libx264 @ 0x55d54aa92680] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d54aa92680] profile High, level 3.1
# [libx264 @ 0x55d54aa92680] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=12 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/home/sanjay/Desktop/TNMS_VM/data/videoclips/xyz/36/clip.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 0
#     compatible_brands: mp41avc1
#     encoder         : Lavf58.29.100
#     Stream #0:0(eng): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], q=-1--1, 25 fps, 12800 tbn, 25 tbc (default)
#     Metadata:
#       creation_time   : 2021-08-26T15:19:56.000000Z
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame=  124 fps= 36 q=-1.0 Lsize=    2866kB time=00:00:04.88 bitrate=4810.2kbits/s speed=1.42x
# video:2863kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.081074%
# [libx264 @ 0x55d54aa92680] frame I:1     Avg QP:23.58  size:149512
# [libx264 @ 0x55d54aa92680] frame P:31    Avg QP:24.51  size: 57593
# [libx264 @ 0x55d54aa92680] frame B:92    Avg QP:30.65  size: 10829
# [libx264 @ 0x55d54aa92680] consecutive B-frames:  0.8%  0.0%  2.4% 96.8%
# [libx264 @ 0x55d54aa92680] mb I  I16..4:  2.8% 50.6% 46.6%
# [libx264 @ 0x55d54aa92680] mb P  I16..4:  0.6%  2.0%  2.5%  P16..4: 39.8% 26.4% 15.4%  0.0%  0.0%    skip:13.4%
# [libx264 @ 0x55d54aa92680] mb B  I16..4:  0.0%  0.0%  0.2%  B16..8: 57.2%  8.1%  2.2%  direct: 1.6%  skip:30.6%  L0:49.6% L1:38.2% BI:12.2%
# [libx264 @ 0x55d54aa92680] 8x8 transform intra:41.5% inter:27.0%
# [libx264 @ 0x55d54aa92680] coded y,uvDC,uvAC intra: 82.4% 42.0% 16.3% inter: 20.9% 7.6% 2.5%
# [libx264 @ 0x55d54aa92680] i16 v,h,dc,p: 18% 32% 14% 36%
# [libx264 @ 0x55d54aa92680] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 23% 18%  4%  6%  6%  8%  6%  7%
# [libx264 @ 0x55d54aa92680] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 28% 12%  4%  5%  5%  8%  6%  5%
# [libx264 @ 0x55d54aa92680] i8c dc,h,v,p: 55% 23% 17%  5%
# [libx264 @ 0x55d54aa92680] Weighted P-Frames: Y:9.7% UV:3.2%
# [libx264 @ 0x55d54aa92680] ref P L0: 62.6% 14.2% 18.7%  4.0%  0.5%
# [libx264 @ 0x55d54aa92680] ref B L0: 91.8%  7.5%  0.7%
# [libx264 @ 0x55d54aa92680] ref B L1: 96.5%  3.5%
# [libx264 @ 0x55d54aa92680] kb/s:4727.76
# 0
